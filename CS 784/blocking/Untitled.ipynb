# %%
print "Hello world"
# Out:
# Hello world

# %%
import magellan as mg
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-2ce1b4249d6f> in <module>()
# ----> 1 import magellan as mg
#
# ImportError: No module named magellan

# %%
mg
# Out:
# <module 'magellan' from 'C:\Anaconda\lib\site-packages\magellan-0.1-py2.7.egg\magellan\__init__.pyc'>

# %%
ab = mg.AttrEquivalenceBlocker()

# %%
ob = mg.OverlapBlocker()

# %%
A = mg.read_csv('test.csv',key='filename')

# %%
A.dtypes
# Out:
# filename               object
# book_name              object
# contributors           object
# Hardcover              object
# Paperback              object
# NOOK Book              object
# Audiobook             float64
# ISBN-13                 int64
# Series                float64
# Publisher              object
# Publication Date      float64
# Sales rank             object
# Pages                   int64
# Product dimensions     object
# dtype: object

# %%
A = A.applymap(str)

# %%
A
# Out:
#   filename                                          book_name  \
# 0   0.html  A Guide to the Project Management Body of Know...
# 1   1.html                     Windows 10: The Missing Manual
# 2   2.html  The Phoenix Project: A Novel about IT, DevOps,...
#
#                             contributors Hardcover Paperback NOOK Book  \
# 0           Project Management Institute       nan   $38.17        nan
# 1                            David Pogue       nan   $23.41    $19.99
# 2  Gene Kim# Kevin Behr# George Spafford             $13.17     $9.99
#
#   Audiobook        ISBN-13 Series                     Publisher  \
# 0       nan  9781935589679    nan  Project Management Institute
# 1       nan  9781491947173    nan  O'Reilly Media, Incorporated
# 2       nan  9780988262508    nan           IT Revolution Press
#
#   Publication Date Sales rank Pages            Product dimensions
# 0              nan        332   589  10.86(w) x 8.26(h) x 1.24(d)
# ...

# %%
A.dtypes
# Out:
# filename              object
# book_name             object
# contributors          object
# Hardcover             object
# Paperback             object
# NOOK Book             object
# Audiobook             object
# ISBN-13               object
# Series                object
# Publisher             object
# Publication Date      object
# Sales rank            object
# Pages                 object
# Product dimensions    object
# dtype: object

# %%
B = mg.read_csv('tableB.csv',key='ID')

# %%
B
# Out:
#         ID                                            "Title"  \
# 0        1                            Steve Jobs: A Biography
# 1        2          Introduction to Control System Technology
# 2        3  Computer Assisted Structural Analysis and Mode...
# 3        4  Computer Numerical Control Programming of Mach...
# 4        5  Pascal Programming and Problem Solving (4th Ed...
# 5        6                       Computer Networking Concepts
# 6        7                       Digital Computer Electronics
# 7        8                Digital Principles and Applications
# 8        9  Experiencing Music Technology: Software, Data,...
# 9       10  Communication Technology (Series in Communicat...
# 10      11  Handbook of Computer Communication Stds Volume...
# 11      12  Robotics: Basic Analysis and Design (The Oxfor...
# 12      13  Multimedia and the Web: Creating Digital Excit...
# 13      14  Cyber War: The Next Threat to National Securit...
# ...

# %%
A
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bf072e911907> in <module>()
# ----> 1 A
#
# NameError: name 'A' is not defined
